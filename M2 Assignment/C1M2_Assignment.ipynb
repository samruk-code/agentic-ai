# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a academic and technical writer and Your job is to write an eassay given topic.
    The essay should be structured, gramatically correct, and cohesive.
    This is the topic: {topic}, you write about.
    
    The output should only be essay draft.
    """

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are great at giving feedback about given essay draft. Your feedback must be critical and constructive.
    and It must cover areas like structure, clarity, strength of argument, and writing style.
    This is the draft: {draft} you should give feedback.
    
    The output should only be feedback.
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f""";
    Your job is to revise the given original draft essay based on the reflection given to that essay.
    You should use the reflection to guide the revision, The revision should improve clarity,
    coherence, argument strength, and overall flow.
    
    This is the original essay {original_draft}.
    This is the reflection {reflection}
    
    The output should only be revised essay.
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: Government Regulation of Social Media Platforms: A Necessary Step or an Overreach?
#
# Introduction
#
# In the digital age, social media platforms have become integral parts of our daily lives. With billions of users worldwide, platforms like Facebook, Twitter, Instagram, and TikTok wield immense influence over public discourse, politics, and personal interactions. However, their role in spreading misinformation, enabling cyberbullying, and violating user privacy has sparked a global debate on whether the government should regulate these platforms. While government intervention could potentially curb some of these issues, it also poses significant challenges related to free speech and innovation. This essay will explore the arguments for and against the government regulation of social media platforms, considering the potential benefits and drawbacks such actions might entail.
#
# Arguments for Government Regulation
#
# One of the primary arguments in favor of government regulation is the need to combat misinformation and protect public safety. Social media platforms have been criticized for their role in the dissemination of false information, particularly concerning health crises, elections, and social issues. Government oversight could help ensure that platforms develop and enforce stringent policies against the spread of misinformation, thereby upholding the integrity of information shared online.
#
# Furthermore, there is a pressing need to address issues of privacy and data protection on these platforms. Social media networks often collect vast amounts of personal data from their users, sometimes without clear consent or transparency regarding how this data is used. Government regulation could mandate greater transparency and protect users from unethical data practices, ensuring that their personal information is handled responsibly.
#
# Additionally, regulation might provide a framework to address online harassment and cyberbullying, which have real-world consequences. By imposing strict penalties on platforms that do not adequately address these issues, governments can create safer environments for users, protecting especially vulnerable populations such as minors.
#
# Arguments Against Government Regulation
#
# Despite these potential benefits, there are significant concerns surrounding the regulation of social media by the government. A primary fear is the threat to free speech. There is a risk that government involvement could lead to censorship, stifling the free exchange of ideas that is central to the ethos of social media. If governments can dictate what content is permissible, it may result in the suppression of dissenting voices and minority opinions, which goes against democratic principles.
#
# Moreover, the dynamic nature of social media technology poses challenges to governmental regulation. Social media platforms are constantly evolving, and government regulations might not be able to keep pace with technological advancements. Overly stringent regulations could stifle innovation and inhibit the development of new social technologies, potentially placing nations that heavily regulate their digital environments at a competitive disadvantage.
#
# Additionally, government regulation could create a one-size-fits-all approach that may not consider the unique features and user bases of different platforms. Such uniform regulation might not be suitable for all platforms, leading to inefficiencies and unintended consequences.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government remains a complex and contentious issue. While regulation could address critical issues like misinformation, privacy, and online safety, it also introduces potential risks to free speech, innovation, and the adaptability of regulation to technological change. A balanced approach, potentially involving multi-stakeholder cooperation between governments, social media companies, and civil society, might be the most effective path forward. Through collaboration, it is possible to develop frameworks that protect users without stifling the dynamism and openness that characterize social media platforms. Ultimately, any decision to regulate must carefully weigh the protection of public interests against the preservation of the freedoms that the digital age has to offer.
#
# 🧠 Feedback:
#
# Here is detailed, critical, and constructive feedback covering structure, clarity, strength of argument, and writing style:
#
# 1. Structure
#   • Introduction
#     – Strength: You open with a clear context (“digital age,” “billions of users”) that signals why regulation matters.
#     – Improvement: Your thesis (“This essay will explore…”) is functional but could be stronger by stating your own stance or hinting at the balance you’ll strike. For example, “This essay argues that while some regulation is necessary, it must be carefully calibrated to protect free speech and innovation.”
#   • Body
#     – Strength: You divide arguments neatly into “for” and “against,” which helps readers follow your logic.
#     – Improvement: Each subsection could benefit from more focused topic sentences. For instance, the “misinformation” paragraph could start with “Misinformation on social media represents a direct threat to public health and democratic processes.”
#     – Evidence: You describe problems (misinformation, privacy, cyberbullying) well but lack concrete examples or statistics. Citing a specific event (e.g., the 2016 election, Cambridge Analytica) would strengthen your points.
#     – Counterarguments: You mention free speech and innovation concerns, but you could engage more deeply—for example, by exploring how self-regulation has failed or succeeded, or by comparing different regulatory models (EU’s Digital Services Act vs. U.S. approach).
#   • Conclusion
#     – Strength: You reiterate the complexity and call for multi-stakeholder cooperation, which aligns with the balanced tone.
#     – Improvement: Instead of ending on a general note, you could suggest next steps (e.g., pilot regulation in specific regions, an independent oversight body, or public reporting requirements). A sharper “call to action” would give your conclusion more punch.
#
# 2. Clarity
#   • Strength: Overall language is straightforward and accessible. Sentences are generally concise.
#   • Improvement: A few sentences are packed with multiple ideas, which can blur your point. For example: “Government intervention could potentially curb some of these issues, it also poses significant challenges…” could be split into two sentences for emphasis.
#   • Improvement: Watch for passive constructions (“platforms have been criticized”). Active voice (“Critics argue that platforms…”) can make your prose more dynamic.
#
# 3. Strength of Argument
#   • Strength: You present both sides evenly and acknowledge nuances. This impartial approach shows critical thinking.
#   • Improvement: Your arguments feel somewhat generic. To persuade an academic or policy audience, integrate concrete data, case studies, or expert opinions.
#   • Improvement: Anticipate and address a key counterpoint more thoroughly—e.g., that algorithms, not just users, spread misinformation, so any regulation must target algorithmic transparency rather than only content moderation.
#   • Improvement: Assess feasibility and trade-offs more critically. You say regulation “could mandate greater transparency,” but how enforceable is that globally? Is there an economic cost to platforms?
#
# 4. Writing Style
#   • Strength: Tone is appropriate for an academic essay—measured and balanced.
#   • Improvement: Vary sentence beginnings to avoid repetitive patterns like “Social media platforms…” or “Government regulation…”
#   • Improvement: Introduce occasional rhetorical questions or hypothetical scenarios (“What happens when a single government decides what counts as ‘misinformation’?”) to engage readers.
#   • Improvement: Trim filler phrases (“there is a pressing need,” “it also poses significant challenges”). Be direct: “Regulation must address privacy concerns and data misuse.”
#
# Overall Recommendation
#   • Deepen your research with concrete examples and data.
#   • Sharpen thesis and topic sentences for stronger guideposts.
#   • Enhance the persuasiveness of both sides by engaging more directly with real-world cases and the mechanics of how regulation would work.
#   • Refine style with active voice, varied sentence structure, and strategic use of questions or scenarios.
#
# By adding specificity and tightening your prose, you can transform a solid balanced overview into a compelling, authoritative analysis of social media regulation.
# ✍️ Revised:
#
# Title: Government Regulation of Social Media Platforms: A Necessary Step or an Overreach?
#
# Introduction
#
# In the digital age, social media platforms have become integral to our daily lives, influencing public discourse, politics, and personal interactions on a global scale. Platforms like Facebook, Twitter, Instagram, and TikTok, with billions of users worldwide, hold significant power. However, their roles in spreading misinformation, enabling cyberbullying, and violating user privacy have sparked a global debate on the necessity of government regulation. This essay argues that while some regulation of social media platforms is necessary to address these issues, it must be carefully calibrated to protect free speech and foster innovation.
#
# Arguments for Government Regulation
#
# Misinformation on social media represents a direct threat to public health and democratic processes. These platforms have faced criticism for their role in disseminating false information, particularly during events like the 2016 U.S. presidential election and the COVID-19 pandemic. Government oversight could ensure stringent policies against misinformation, safeguarding the integrity of online discourse.
#
# Moreover, addressing privacy and data protection on social media platforms is crucial. Companies frequently gather vast amounts of personal data, often without clear user consent or transparency. Government regulation could enforce transparency and ethical data practices, exemplified by policies like the EU's General Data Protection Regulation (GDPR), ensuring personal information is handled responsibly.
#
# Regulation might also provide a framework to combat online harassment and cyberbullying, which have tangible real-world consequences. By imposing strict penalties on platforms that inadequately address these issues, governments can create safer environments for users—especially vulnerable groups such as minors.
#
# Arguments Against Government Regulation
#
# Despite these potential benefits, significant concerns exist regarding government regulation of social media. A primary fear is the erosion of free speech. Government involvement could lead to censorship, stifling the free exchange of ideas fundamental to social media. When governments control permissible content, it risks suppressing dissenting voices and minority opinions, undermining democratic principles.
#
# Additionally, the dynamic nature of social media technology presents challenges to effective regulation. Platforms evolve rapidly, and government regulations may struggle to keep pace with technological advancements. Overly stringent rules could stifle innovation, potentially disadvancing nations with heavy digital regulation.
#
# Furthermore, regulation risks imposing a one-size-fits-all approach that overlooks the diverse characteristics of different platforms. Such uniformity could lead to inefficiencies and unintended consequences, demonstrating the need for nuanced, adaptable legislation.
#
# Conclusion
#
# The question of whether to regulate social media platforms remains complex and contentious. While regulation can tackle critical issues like misinformation, privacy, and safety online, it also poses risks to free speech, innovation, and the adaptability of regulation to technological change. A balanced approach, involving cooperation between governments, social media companies, and civil society, is essential. Exploring regulatory frameworks, such as independent oversight bodies or public reporting requirements, could offer ways to protect users while preserving the dynamism and openness of social platforms. Ultimately, any regulatory decisions must weigh public interest protection against preserving freedoms in the digital age, fostering a future where social media serves society effectively and ethically.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Government Regulation of Social Media Platforms: A Necessary Step or an Overreach?
#
# Introduction
#
# In the digital age, social media platforms have become integral parts of our daily lives. With billions of users worldwide, platforms like Facebook, Twitter, Instagram, and TikTok wield immense influence over public discourse, politics, and personal interactions. However, their role in spreading misinformation, enabling cyberbullying, and violating user privacy has sparked a global debate on whether the government should regulate these platforms. While government intervention could potentially curb some of these issues, it also poses significant challenges related to free speech and innovation. This essay will explore the arguments for and against the government regulation of social media platforms, considering the potential benefits and drawbacks such actions might entail.
#
# Arguments for Government Regulation
#
# One of the primary arguments in favor of government regulation is the need to combat misinformation and protect public safety. Social media platforms have been criticized for their role in the dissemination of false information, particularly concerning health crises, elections, and social issues. Government oversight could help ensure that platforms develop and enforce stringent policies against the spread of misinformation, thereby upholding the integrity of information shared online.
#
# Furthermore, there is a pressing need to address issues of privacy and data protection on these platforms. Social media networks often collect vast amounts of personal data from their users, sometimes without clear consent or transparency regarding how this data is used. Government regulation could mandate greater transparency and protect users from unethical data practices, ensuring that their personal information is handled responsibly.
#
# Additionally, regulation might provide a framework to address online harassment and cyberbullying, which have real-world consequences. By imposing strict penalties on platforms that do not adequately address these issues, governments can create safer environments for users, protecting especially vulnerable populations such as minors.
#
# Arguments Against Government Regulation
#
# Despite these potential benefits, there are significant concerns surrounding the regulation of social media by the government. A primary fear is the threat to free speech. There is a risk that government involvement could lead to censorship, stifling the free exchange of ideas that is central to the ethos of social media. If governments can dictate what content is permissible, it may result in the suppression of dissenting voices and minority opinions, which goes against democratic principles.
#
# Moreover, the dynamic nature of social media technology poses challenges to governmental regulation. Social media platforms are constantly evolving, and government regulations might not be able to keep pace with technological advancements. Overly stringent regulations could stifle innovation and inhibit the development of new social technologies, potentially placing nations that heavily regulate their digital environments at a competitive disadvantage.
#
# Additionally, government regulation could create a one-size-fits-all approach that may not consider the unique features and user bases of different platforms. Such uniform regulation might not be suitable for all platforms, leading to inefficiencies and unintended consequences.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government remains a complex and contentious issue. While regulation could address critical issues like misinformation, privacy, and online safety, it also introduces potential risks to free speech, innovation, and the adaptability of regulation to technological change. A balanced approach, potentially involving multi-stakeholder cooperation between governments, social media companies, and civil society, might be the most effective path forward. Through collaboration, it is possible to develop frameworks that protect users without stifling the dynamism and openness that characterize social media platforms. Ultimately, any decision to regulate must carefully weigh the protection of public interests against the preservation of the freedoms that the digital age has to offer.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here is detailed, critical, and constructive feedback covering structure, clarity, strength of argument, and writing style:
#
# 1. Structure
#   • Introduction
#     – Strength: You open with a clear context (“digital age,” “billions of users”) that signals why regulation matters.
#     – Improvement: Your thesis (“This essay will explore…”) is functional but could be stronger by stating your own stance or hinting at the balance you’ll strike. For example, “This essay argues that while some regulation is necessary, it must be carefully calibrated to protect free speech and innovation.”
#   • Body
#     – Strength: You divide arguments neatly into “for” and “against,” which helps readers follow your logic.
#     – Improvement: Each subsection could benefit from more focused topic sentences. For instance, the “misinformation” paragraph could start with “Misinformation on social media represents a direct threat to public health and democratic processes.”
#     – Evidence: You describe problems (misinformation, privacy, cyberbullying) well but lack concrete examples or statistics. Citing a specific event (e.g., the 2016 election, Cambridge Analytica) would strengthen your points.
#     – Counterarguments: You mention free speech and innovation concerns, but you could engage more deeply—for example, by exploring how self-regulation has failed or succeeded, or by comparing different regulatory models (EU’s Digital Services Act vs. U.S. approach).
#   • Conclusion
#     – Strength: You reiterate the complexity and call for multi-stakeholder cooperation, which aligns with the balanced tone.
#     – Improvement: Instead of ending on a general note, you could suggest next steps (e.g., pilot regulation in specific regions, an independent oversight body, or public reporting requirements). A sharper “call to action” would give your conclusion more punch.
#
# 2. Clarity
#   • Strength: Overall language is straightforward and accessible. Sentences are generally concise.
#   • Improvement: A few sentences are packed with multiple ideas, which can blur your point. For example: “Government intervention could potentially curb some of these issues, it also poses significant challenges…” could be split into two sentences for emphasis.
#   • Improvement: Watch for passive constructions (“platforms have been criticized”). Active voice (“Critics argue that platforms…”) can make your prose more dynamic.
#
# 3. Strength of Argument
#   • Strength: You present both sides evenly and acknowledge nuances. This impartial approach shows critical thinking.
#   • Improvement: Your arguments feel somewhat generic. To persuade an academic or policy audience, integrate concrete data, case studies, or expert opinions.
#   • Improvement: Anticipate and address a key counterpoint more thoroughly—e.g., that algorithms, not just users, spread misinformation, so any regulation must target algorithmic transparency rather than only content moderation.
#   • Improvement: Assess feasibility and trade-offs more critically. You say regulation “could mandate greater transparency,” but how enforceable is that globally? Is there an economic cost to platforms?
#
# 4. Writing Style
#   • Strength: Tone is appropriate for an academic essay—measured and balanced.
#   • Improvement: Vary sentence beginnings to avoid repetitive patterns like “Social media platforms…” or “Government regulation…”
#   • Improvement: Introduce occasional rhetorical questions or hypothetical scenarios (“What happens when a single government decides what counts as ‘misinformation’?”) to engage readers.
#   • Improvement: Trim filler phrases (“there is a pressing need,” “it also poses significant challenges”). Be direct: “Regulation must address privacy concerns and data misuse.”
#
# Overall Recommendation
#   • Deepen your research with concrete examples and data.
#   • Sharpen thesis and topic sentences for stronger guideposts.
#   • Enhance the persuasiveness of both sides by engaging more directly with real-world cases and the mechanics of how regulation would work.
#   • Refine style with active voice, varied sentence structure, and strategic use of questions or scenarios.
#
# By adding specificity and tightening your prose, you can transform a solid balanced overview into a compelling, authoritative analysis of social media regulation.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Government Regulation of Social Media Platforms: A Necessary Step or an Overreach?
#
# Introduction
#
# In the digital age, social media platforms have become integral to our daily lives, influencing public discourse, politics, and personal interactions on a global scale. Platforms like Facebook, Twitter, Instagram, and TikTok, with billions of users worldwide, hold significant power. However, their roles in spreading misinformation, enabling cyberbullying, and violating user privacy have sparked a global debate on the necessity of government regulation. This essay argues that while some regulation of social media platforms is necessary to address these issues, it must be carefully calibrated to protect free speech and foster innovation.
#
# Arguments for Government Regulation
#
# Misinformation on social media represents a direct threat to public health and democratic processes. These platforms have faced criticism for their role in disseminating false information, particularly during events like the 2016 U.S. presidential election and the COVID-19 pandemic. Government oversight could ensure stringent policies against misinformation, safeguarding the integrity of online discourse.
#
# Moreover, addressing privacy and data protection on social media platforms is crucial. Companies frequently gather vast amounts of personal data, often without clear user consent or transparency. Government regulation could enforce transparency and ethical data practices, exemplified by policies like the EU's General Data Protection Regulation (GDPR), ensuring personal information is handled responsibly.
#
# Regulation might also provide a framework to combat online harassment and cyberbullying, which have tangible real-world consequences. By imposing strict penalties on platforms that inadequately address these issues, governments can create safer environments for users—especially vulnerable groups such as minors.
#
# Arguments Against Government Regulation
#
# Despite these potential benefits, significant concerns exist regarding government regulation of social media. A primary fear is the erosion of free speech. Government involvement could lead to censorship, stifling the free exchange of ideas fundamental to social media. When governments control permissible content, it risks suppressing dissenting voices and minority opinions, undermining democratic principles.
#
# Additionally, the dynamic nature of social media technology presents challenges to effective regulation. Platforms evolve rapidly, and government regulations may struggle to keep pace with technological advancements. Overly stringent rules could stifle innovation, potentially disadvancing nations with heavy digital regulation.
#
# Furthermore, regulation risks imposing a one-size-fits-all approach that overlooks the diverse characteristics of different platforms. Such uniformity could lead to inefficiencies and unintended consequences, demonstrating the need for nuanced, adaptable legislation.
#
# Conclusion
#
# The question of whether to regulate social media platforms remains complex and contentious. While regulation can tackle critical issues like misinformation, privacy, and safety online, it also poses risks to free speech, innovation, and the adaptability of regulation to technological change. A balanced approach, involving cooperation between governments, social media companies, and civil society, is essential. Exploring regulatory frameworks, such as independent oversight bodies or public reporting requirements, could offer ways to protect users while preserving the dynamism and openness of social platforms. Ultimately, any regulatory decisions must weigh public interest protection against preserving freedoms in the digital age, fostering a future where social media serves society effectively and ethically.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
